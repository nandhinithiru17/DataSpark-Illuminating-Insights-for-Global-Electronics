# %%
#import packages
from sqlalchemy import create_engine,text
from sqlalchemy import DECIMAL
import pandas as pd

#define variables
username = 'root'
password = 'PRANITHAA17@'
host = 'localhost'
port = '3306'
database = 'global_electronics'

# %%
# Step 1: Now connect to the newly created/existing database
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}')

# %%
connecting_string="mysql+pymysql://root:PRANITHAA17@/localhost:3306/global_electronics"

# %%
import pymysql

# %%
import pymysql

# Correct connection parameters
connection = pymysql.connect(
    host='localhost',  # Corrected hostname
    user='root',
    password='PRANITHAA17@',
    database='global_electronics',
    port=3306
)

try:
    with connection.cursor() as cursor:
        cursor.execute("SELECT VERSION();")
        version = cursor.fetchone()
        print("Database version:", version)
finally:
    connection.close()
# Out:
# Database version: ('8.0.40',)

# %%
engine = create_engine('mysql+pymysql://username:password@localhost:3306/database_name')

# %%
# Step 4: Load cleaned datasets individually with specified encoding
customers_df = pd.read_csv(r"C:\Users\THIRU\OneDrive\Desktop\data_illuminate\customers.csv",encoding='ISO-8859-1')
rates_df = pd.read_csv(r'C:\Users\THIRU\OneDrive\Desktop\data_illuminate\rates.csv')
products_df = pd.read_csv(r'C:\Users\THIRU\OneDrive\Desktop\data_illuminate\products.csv')
sales_df = pd.read_csv(r'C:\Users\THIRU\OneDrive\Desktop\data_illuminate\sales.csv')
stores_df = pd.read_csv(r'C:\Users\THIRU\OneDrive\Desktop\data_illuminate\stores.csv')

# %%
final_df = pd.concat([stores_df, sales_df, products_df, customers_df, rates_df], ignore_index=True)

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:your_password@localhost:3306/your_database')

try:
    with engine.connect() as conn:
        print("Connection successful!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connection failed: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Load the combined DataFrame into the SQL table
final_df.to_sql(
    'combined_table',
    con=engine,
    if_exists='replace',
    index=False
)

print("Data successfully loaded into the SQL table 'combined_table'.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\THIRU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File c:\Users\THIRU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File c:\Users\THIRU\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...
